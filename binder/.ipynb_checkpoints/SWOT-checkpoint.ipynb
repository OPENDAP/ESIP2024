# %% [markdown]
# <span style='color:#009999'> <span style='font-family:serif'> <font size="15"> **SWOT Nadir NALT GDR L2**<span style='color:#0066cc'>
#
# <img src="img/SWOT.png" alt="drawing" width="500"/>
#
# <span style='color:#ff6666'><font size="5">Requirements
# 1. <font size="3"><span style='color:Black'> Have a Bearer Token for EarthData in the Cloud (See Getting Started Notebook).
# 2. <font size="3"><span style='color:Black'> Upload the Bearer Token from local file`token.json`
#
#
#
#  <span style='color:#ff6666'><font size="5">Objectives
# - <font size="3"><span style='color:Black'> Understand `Dimensions`, `Groups`, `Maps` and `Arrays` in the DAP4 model.
# - <font size="3"><span style='color:Black'> Develop understanding of metadata of remote files accessed via OPeNDAP.
# - <font size="3"><span style='color:Black'> To demonstrate a workflow for remote access and plotting of Complex (**Level 2** with Groups)  SWOT Data via OPeNDAP
#
#
#
# <span style='color:#ff6666'><font size="5"> Browsing Data:
#
# <font size="3"><span style='color:Black'> Broad information about the dataset can be found in the PODAAC website (see [here](https://podaac.jpl.nasa.gov/dataset/SWOT_L2_NALT_GDR_2.0))

# %%
import matplotlib.pyplot as plt
import numpy as np
import requests
from pydap.client import open_url
import json
import cartopy.crs as ccrs

# %% [markdown]
# <span style='font-family:serif'> <font size="5.5"><span style='color:#0066cc'> **Access EARTHDATA**
#
# <font size="3"><span style='color:Black'> The access link can be found at [PODACC](https://podaac.jpl.nasa.gov/dataset/SWOT_L2_NALT_GDR_2.0). This may require to be logged on to EarthDataLogin. There is data for 2023 and 2024.

# %%
data_url1 = 'https://opendap.earthdata.nasa.gov/collections/C2799438313-POCLOUD/granules/SWOT_GPR_2PfP507_010_20230501_003247_20230501_012352'
data_url2 = 'https://opendap.earthdata.nasa.gov/collections/C2799438313-POCLOUD/granules/SWOT_GPN_2PfP006_350_20231115_003412_20231115_012539'

# %% [markdown]
# <span style='font-family:serif'> <font size="5.5"><span style='color:#0066cc'> **Import Token Authorization and create Session**

# %%
# load token json data
with open('token.json', 'r') as fp:
    Authorization = json.load(fp)

# pass Token Authorization to a new Session.
my_session = requests.Session()
my_session.headers = Authorization

# %% [markdown]
# <span style='font-family:serif'> <font size="5.5"><span style='color:#0066cc'> **Create dataset access via pydap**

# %%
# %%time
dataset1 = open_url(data_url1, session=my_session, protocol="dap4")
# Out:
# CPU times: user 61.3 ms, sys: 20.8 ms, total: 82.1 ms
# Wall time: 1.43 s

# %%
dataset1.tree()
# Out:
# .SWOT_GPR_2PfP507_010_20230501_003247_20230501_012352.nc
# └──data_01
#    ├──time
#    ├──longitude
#    ├──latitude
#    ├──rad_side_2_rain_flag
#    ├──rad_wet_tropo_cor
#    ├──depth_or_elevation
#    ├──rad_qual
#    ├──rad_water_vapor
#    ├──rad_side_2_sea_ice_flag
#    ├──pole_tide
#    ├──model_dry_tropo_cor_zero_altitude
#    ├──solid_earth_tide
#    ├──dac
#    ├──rad_side_1_surface_type_flag
#    ├──surface_classification_flag
#    ├──time_tai
#    ├──altitude
#    ├──rad_side_1_rain_flag
#    ├──rad_side_1_sea_ice_flag
#    ├──ice_flag
#    ├──rad_wet_tropo_cor_interp_qual
#    ├──inv_bar_cor
#    ├──ocean_tide_fes
#    ├──mean_dynamic_topography
#    ├──rad_side_2_surface_type_flag
#    ├──alt_qual
#    ├──internal_tide_hret
#    ├──meteo_map_availability_flag
#    ├──wind_speed_alt
#    ├──wind_speed_alt_mle3
#    ├──rain_flag
#    ├──mean_sea_surface_cnescls
#    ├──geo_qual
#    ├──rad_cloud_liquid_water
#    └──ku
#       ├──iono_cor_alt_filtered_mle3
#       ├──sea_state_bias_mle3
#       ├──wvf_main_class
#       ├──iono_cor_alt_filtered
#       ├──range_ocean
#       ├──ssha_mle3
#       ├──sig0_ocean
#       ├──sig0_ocean_mle3
#       ├──sea_state_bias
#       ├──swh_ocean
#       ├──range_ocean_mle3
#       ├──ssha
#       └──swh_ocean_mle3

# %% [markdown]
# <span style='font-family:serif'> <font size="5.5"><span style='color:#0066cc'> **This is a dataset pointing to a remote data location**
#
#
# <font size="3"><span style='color:Black'> Data remains remote, no data has been downloaded.

# %%
dataset1['data_01/ku/swh_ocean'].shape
# Out:
# (2880,)

# %%
dataset1['data_01/time'].shape
# Out:
# (2880,)

# %%
# print('total array memory: ', dataset1.nbytes/1e9)

# %% [markdown]
# <span style='font-family:serif'> <font size="5.5"><span style='color:#0066cc'> **Inspect the values**
#
#
# - <font size="3"><span style='color:Black'> `longitude`
# - <font size="3"><span style='color:Black'> `latitude`
# - <font size="3"><span style='color:Black'> `time`
#
#
# <font size="3"><span style='color:Black'>  What do you notice about the range values?

# %%
dataset1['data_01/ku/swh_ocean'].attributes
# Out:
# {'_FillValue': 32767,
#  'long_name': 'Ku band corrected significant waveheight',
#  'standard_name': 'sea_surface_wave_significant_height',
#  'units': 'm',
#  'scale_factor': 0.001,
#  'coordinates': '/data_01/longitude /data_01/latitude',
#  'comment': 'All instrumental corrections included, i.e. modeled instrumental errors correction (swh_cor_ocean_model_instr) and system bias',
#  'path': '/data_01/ku'}

# %%
dataset1['data_01/ku/swh_ocean_mle3'].attributes
# Out:
# {'_FillValue': 32767,
#  'long_name': 'Ku band corrected significant waveheight (MLE3 retracking)',
#  'standard_name': 'sea_surface_wave_significant_height',
#  'units': 'm',
#  'scale_factor': 0.001,
#  'coordinates': '/data_01/longitude /data_01/latitude',
#  'comment': 'All instrumental corrections included, i.e. modeled instrumental errors correction (swh_cor_ocean_mle3_model_instr) and system bias',
#  'path': '/data_01/ku'}

# %%
dataset1['data_01/ku/swh_ocean_mle3'].dimensions
# Out:
# ['time']

# %%
dataset1['data_01/time'].attributes
# Out:
# {'long_name': 'time in UTC',
#  'standard_name': 'time',
#  'calendar': 'gregorian',
#  'units': 'seconds since 2000-01-01 00:00:00.0',
#  'comment': 'Time of measurement in seconds in the UTC time scale since 1 Jan 2000 00:00:00 UTC. [tai_utc_difference] is the difference between TAI and UTC reference time (seconds) for the first measurement of the data set. If a leap second occurs within the data set, the attribute [leap_second] is set to the UTC time at which the leap second occurs',
#  'tai_utc_difference': 37.0,
#  'leap_second': '0000-00-00 00:00:00',
#  'path': '/data_01'}

# %%
# %%time
swh_ocean = dataset1['/data_01/ku/swh_ocean'][:] # downloads as BaseType - a thin wrapper for numpy arrays
# Out:
# CPU times: user 31.6 ms, sys: 5.79 ms, total: 37.4 ms
# Wall time: 3.41 s

# %% [markdown]
# <span style='font-family:serif'> <font size="5.5"><span style='color:#0066cc'> **Maps**
#
# <font size="3"><span style='color:Black'>  Refers to the coverage of the Satellite track. This is, how the trajectory "**maps**" with time (dimension)

# %%
swh_ocean.Maps
# Out:
# ('/data_01/longitude', '/data_01/latitude')

# %%
# %%time
longitude1 = dataset1[swh_ocean.Maps[0]][:]
latitude1 = dataset1[swh_ocean.Maps[1]][:]
# Out:
# CPU times: user 69.2 ms, sys: 15.1 ms, total: 84.3 ms
# Wall time: 6.95 s

# %%
longitude1.attributes
# Out:
# {'_FillValue': 2147483647,
#  'long_name': 'longitude',
#  'standard_name': 'longitude',
#  'units': 'degrees_east',
#  'scale_factor': 1e-06,
#  'comment': 'East longitude relative to Greenwich meridian. See SWOT Nadir Altimeter User Handbook. Associated quality flag is orb_state_diode_flag for the OGDR products, orb_state_rest_flag for the IGDR and GDR products',
#  'path': '/data_01',
#  'checksum': array([4151025818], dtype=uint32),
#  'Maps': ()}

# %%
latitude1.attributes
# Out:
# {'_FillValue': 2147483647,
#  'long_name': 'latitude',
#  'standard_name': 'latitude',
#  'units': 'degrees_north',
#  'scale_factor': 1e-06,
#  'comment': 'Positive latitude is North latitude, negative latitude is South latitude. See SWOT Nadir Altimeter User Handbook. Associated quality flag is orb_state_diode_flag for the OGDR products, orb_state_rest_flag for the IGDR and GDR products',
#  'path': '/data_01',
#  'checksum': array([1388797074], dtype=uint32),
#  'Maps': ()}

# %% [markdown]
# <span style='color:#ff6666'><font size="5">**CF - Conventions**
#
# <font size="3"><span style='color:Black'> In OPeNDAP's metadata rich datasets, each contains standard attributes used to describe missing data, units in which the data is presented, and any stretching/scaling of the values.
#
# - <font size="3"><span style='color:Black'> `standard name`
# - <font size="3"><span style='color:Black'> `units`
# - <font size="3"><span style='color:Black'> `_FillValue`
# - <font size="3"><span style='color:Black'> `scale_factor`
# - <font size="3"><span style='color:Black'> `off_set`
#
# <span style='font-family:serif'> <font size="5.5"><span style='color:#0066cc'> **Decode Values**

# %%
def decode(variable) -> np.ndarray:
    """Decodes the variable BaseType according with atributes:
        _FillValue
        scale_factor
    """
    scale_factor = 1
    _Fill_value = None

    if 'scale_factor' in variable.attributes:
        scale_factor = variable.scale_factor
    if '_FillValue' in variable.attributes:
        data = np.where(variable.data == variable._FillValue, np.nan, variable.data)    
    else:
        data = variable.data
    return scale_factor * data

# %% [markdown]
# <span style='font-family:serif'> <font size="5.5"><span style='color:#0066cc'> **Plotting tools**
#
# <font size="3"><span style='color:Black'> OPeNDAP does NOT a plotting service, but OPeNDAP served data integrates eaasily with plotting packages like
# - <font size="3"><span style='color:Black'> Matplotlib
# - <font size="3"><span style='color:Black'> Cartopy

# %%
plt.figure(figsize=(15, 5))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_global()
ax.coastlines()
plt.scatter(x=decode(longitude1), y=decode(latitude1), c=decode(swh_ocean), marker='.',  cmap='jet')
plt.colorbar().set_label(swh_ocean.name + ' ['+swh_ocean.units+']')

# %% [markdown]
# <span style='color:#ff6666'><font size="5">**Plot Exercise**
#
# <font size="3"><span style='color:Black'> Choose a different variable, over a different time range, access a different OPeNDAP URL. Make sure to
# adjust the:
#
# - longitudes
# - latitudes
# - standard name
# - units

# %%
# %%time
altitude = dataset1['/data_01/altitude'][:]
# Out:
# CPU times: user 37.5 ms, sys: 19.3 ms, total: 56.8 ms
# Wall time: 5.24 s

# %%
plt.figure(figsize=(15, 5))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_global()
ax.coastlines()
plt.scatter(x=decode(longitude1), y=decode(latitude1), c=decode(altitude), marker='.',  cmap='jet')
plt.colorbar().set_label(altitude.name + ' ['+altitude.units+']')

# %%
# %%time
dataset2 = open_url(data_url2, session=my_session, protocol="dap4")
# Out:
# CPU times: user 67.2 ms, sys: 21.6 ms, total: 88.8 ms
# Wall time: 4.07 s

# %%
dataset2.tree()
# Out:
# .SWOT_GPN_2PfP006_350_20231115_003412_20231115_012539.nc
# ├──data_01
# │  ├──time
# │  ├──longitude
# │  ├──latitude
# │  ├──wind_speed_mod_v
# │  ├──mean_dynamic_topography_interp_qual
# │  ├──ocean_tide_fes_interp_qual
# │  ├──mean_sea_surface_dtu
# │  ├──wave_model_map_availability_flag
# │  ├──rad_water_vapor
# │  ├──sst
# │  ├──rad_side_1_land_frac_340
# │  ├──wind_speed_mod_u
# │  ├──distance_to_coast
# │  ├──meteo_measurement_altitude_interp_qual
# │  ├──model_dry_tropo_cor_measurement_altitude
# │  ├──rad_tmb_187
# │  ├──meteo_zero_altitude_interp_qual
# │  ├──pole_tide
# │  ├──rad_tmb_238
# │  ├──surface_slope_cor
# │  ├──rad_side_2_distance_to_land
# │  ├──rad_side_2_land_frac_238
# │  ├──ocean_tide_non_eq
# │  ├──rad_side_2_rain_flag
# │  ├──rad_tb_238
# │  ├──depth_or_elevation
# │  ├──rad_tb_340
# │  ├──rad_tb_187_qual
# │  ├──rad_tb_238_qual
# │  ├──sea_ice_concentration_interp_qual
# │  ├──rad_side_1_distance_to_land
# │  ├──orb_state_diode_flag
# │  ├──rad_side_1_land_frac_187
# │  ├──sig0_cor_atm_source
# │  ├──rad_side_2_sea_ice_flag
# │  ├──rad_side_2_land_frac_340
# │  ├──alt_state_band_seq_flag
# │  ├──rain_rate
# │  ├──rad_wet_tropo_cor
# │  ├──model_dry_tropo_cor_zero_altitude
# │  ├──solid_earth_tide
# │  ├──load_tide_got
# │  ├──dac
# │  ├──rad_side_1_surface_type_flag
# │  ├──surface_classification_flag
# │  ├──time_tai
# │  ├──altitude
# │  ├──internal_tide_hret_interp_qual
# │  ├──rad_side_1_rain_flag
# │  ├──rad_side_1_sea_ice_flag
# │  ├──mean_wave_direction
# │  ├──ocean_tide_eq
# │  ├──ice_flag
# │  ├──rad_tmb_340
# │  ├──rad_wet_tropo_cor_interp_qual
# │  ├──rad_tb_340_qual
# │  ├──rad_tb_187
# │  ├──inv_bar_cor
# │  ├──geoid
# │  ├──index_first_20hz_measurement
# │  ├──ocean_tide_fes
# │  ├──mean_dynamic_topography
# │  ├──rad_side_2_surface_type_flag
# │  ├──internal_tide_hret
# │  ├──rad_side_2_land_frac_187
# │  ├──ocean_tide_got
# │  ├──altitude_rate
# │  ├──rad_wind_speed
# │  ├──wave_model_interp_qual
# │  ├──orb_state_rest_flag
# │  ├──angle_of_approach_to_coast
# │  ├──meteo_map_availability_flag
# │  ├──wind_speed_alt
# │  ├──wind_speed_alt_adaptive
# │  ├──load_tide_fes
# │  ├──wind_speed_alt_mle3
# │  ├──rain_flag
# │  ├──mean_sea_surface_dtu_interp_qual
# │  ├──mean_sea_surface_cnescls
# │  ├──sea_ice_concentration
# │  ├──mean_wave_period_t02
# │  ├──rad_cloud_liquid_water
# │  ├──model_wet_tropo_cor_zero_altitude
# │  ├──ocean_tide_got_interp_qual
# │  ├──mean_sea_surface_cnescls_interp_qual
# │  ├──rad_side_1_land_frac_238
# │  ├──numtotal_20hz_measurement
# │  ├──model_wet_tropo_cor_measurement_altitude
# │  ├──c
# │  │  ├──swh_cor_ocean_net_instr_qual
# │  │  ├──sea_state_bias_mle3
# │  │  ├──sig0_ocean_numval
# │  │  ├──agc
# │  │  ├──swh_cor_ocean_net_instr
# │  │  ├──range_ocean
# │  │  ├──swh_ocean_rms
# │  │  ├──agc_rms
# │  │  ├──sig0_ocean
# │  │  ├──range_ocean_compression_qual
# │  │  ├──range_cor_ocean_net_instr_qual
# │  │  ├──sea_state_bias_adaptive
# │  │  ├──sig0_ocean_rms
# │  │  ├──sea_state_bias
# │  │  ├──range_ocean_rms
# │  │  ├──alt_state_band_status_flag
# │  │  ├──sig0_ocean_compression_qual
# │  │  ├──swh_ocean_numval
# │  │  ├──swh_ocean
# │  │  ├──sig0_cor_ocean_net_instr_qual
# │  │  ├──swh_ocean_compression_qual
# │  │  ├──sig0_cor_atm
# │  │  ├──range_cor_ocean_net_instr
# │  │  ├──alt_state_c_band_flag
# │  │  ├──range_ocean_numval
# │  │  ├──agc_numval
# │  │  └──sig0_cor_ocean_net_instr
# │  └──ku
# │     ├──iono_cor_alt_filtered_mle3
# │     ├──iono_cor_alt_filtered_adaptive_qual
# │     ├──swh_cor_ocean_net_instr_qual
# │     ├──range_ocean_mle3_rms
# │     ├──iono_cor_alt_adaptive
# │     ├──swh_cor_adaptive_net_instr
# │     ├──sea_state_bias_mle3
# │     ├──off_nadir_angle_wf_ocean_rms
# │     ├──wvf_main_class
# │     ├──range_cor_ocean_mle3_net_instr
# │     ├──iono_cor_alt_filtered_mle3_qual
# │     ├──swh_ocean_mle3_compression_qual
# │     ├──sig0_ocean_numval
# │     ├──agc
# │     ├──swh_cor_ocean_net_instr
# │     ├──iono_cor_alt_filtered
# │     ├──range_ocean
# │     ├──ssha_mle3
# │     ├──sig0_adaptive_rms
# │     ├──swh_ocean_rms
# │     ├──agc_rms
# │     ├──sig0_adaptive
# │     ├──sig0_ocean
# │     ├──range_ocean_compression_qual
# │     ├──sig0_ocean_mle3_numval
# │     ├──range_cor_ocean_net_instr_qual
# │     ├──iono_cor_alt_filtered_qual
# │     ├──sea_state_bias_adaptive
# │     ├──range_adaptive_compression_qual
# │     ├──swh_ocean_mle3_numval
# │     ├──sig0_ocean_mle3
# │     ├──iono_cor_alt_filtered_adaptive
# │     ├──off_nadir_angle_wf_ocean_numval
# │     ├──sig0_ocean_rms
# │     ├──range_cor_adaptive_net_instr
# │     ├──sea_state_bias
# │     ├──range_ocean_mle3_compression_qual
# │     ├──range_ocean_rms
# │     ├──range_adaptive
# │     ├──alt_state_band_status_flag
# │     ├──sig0_ocean_compression_qual
# │     ├──swh_ocean_numval
# │     ├──off_nadir_angle_wf_ocean
# │     ├──swh_adaptive_numval
# │     ├──swh_adaptive_compression_qual
# │     ├──swh_ocean
# │     ├──iono_cor_gim
# │     ├──sig0_cor_ocean_net_instr_qual
# │     ├──iono_cor_alt_mle3
# │     ├──sea_state_bias_3d_mp2
# │     ├──sea_state_bias_adaptive_3d_mp2
# │     ├──sig0_cor_adaptive_net_instr
# │     ├──sig0_adaptive_numval
# │     ├──sig0_cor_ocean_mle3_net_instr
# │     ├──swh_cor_ocean_mle3_net_instr
# │     ├──swh_ocean_compression_qual
# │     ├──sig0_cor_atm
# │     ├──off_nadir_angle_wf_ocean_compression_qual
# │     ├──range_ocean_mle3
# │     ├──range_cor_ocean_net_instr
# │     ├──range_ocean_mle3_numval
# │     ├──ssha
# │     ├──range_adaptive_numval
# │     ├──swh_adaptive_rms
# │     ├──sig0_adaptive_compression_qual
# │     ├──range_adaptive_rms
# │     ├──swh_adaptive
# │     ├──iono_cor_alt
# │     ├──swh_ocean_mle3_rms
# │     ├──swh_ocean_mle3
# │     ├──range_ocean_numval
# │     ├──sig0_ocean_mle3_compression_qual
# │     ├──agc_numval
# │     ├──sig0_ocean_mle3_rms
# │     └──sig0_cor_ocean_net_instr
# └──data_20
#    ├──time
#    ├──longitude
#    ├──latitude
#    ├──model_dry_tropo_cor_measurement_altitude
#    ├──surface_slope_cor
#    ├──distance_to_coast
#    ├──meteo_measurement_altitude_interp_qual
#    ├──index_1hz_measurement
#    ├──alt_state_acq_mode_flag
#    ├──surface_classification_flag
#    ├──time_tai
#    ├──altitude
#    ├──angle_of_approach_to_coast
#    ├──alt_state_track_trans_flag
#    ├──model_wet_tropo_cor_measurement_altitude
#    ├──c
#    │  ├──ice2_qual
#    │  ├──range_ice2
#    │  ├──sigmal_ice2
#    │  ├──range_ocean
#    │  ├──sig0_ocean
#    │  ├──range_ocean_compression_qual
#    │  ├──peakiness
#    │  ├──sig0_ocean_compression_qual
#    │  ├──swh_ocean
#    │  ├──range_ocog
#    │  ├──swh_ocean_compression_qual
#    │  ├──num_iterations_ocean
#    │  ├──mqe_ocean
#    │  ├──slope2_ice2
#    │  ├──mqe_ice2
#    │  ├──sig0_ocog
#    │  ├──sig0_ice2
#    │  ├──slope1_ice2
#    │  └──sig0_leading_edge_ice2
#    └──ku
#       ├──seaice_qual
#       ├──range_seaice
#       ├──num_iterations_adaptive
#       ├──ice2_qual
#       ├──mqe_ocean_mle3
#       ├──wvf_main_class
#       ├──range_ice2
#       ├──swh_ocean_mle3_compression_qual
#       ├──sigmal_ice2
#       ├──num_iterations_ocean_mle3
#       ├──range_ocean
#       ├──sig0_adaptive
#       ├──sig0_ocean
#       ├──range_ocean_compression_qual
#       ├──mqe_adaptive
#       ├──range_tfmra
#       ├──range_adaptive_compression_qual
#       ├──sig0_seaice
#       ├──sig0_ocean_mle3
#       ├──sig0_tfmra
#       ├──peakiness
#       ├──range_ocean_mle3_compression_qual
#       ├──tfmra_qual
#       ├──range_adaptive
#       ├──sig0_ocean_compression_qual
#       ├──off_nadir_angle_wf_ocean
#       ├──swh_adaptive_compression_qual
#       ├──swh_ocean
#       ├──range_ocog
#       ├──ocog_qual
#       ├──swh_ocean_compression_qual
#       ├──off_nadir_angle_wf_ocean_compression_qual
#       ├──range_ocean_mle3
#       ├──num_iterations_ocean
#       ├──mqe_ocean
#       ├──sig0_adaptive_compression_qual
#       ├──swh_adaptive
#       ├──slope2_ice2
#       ├──mqe_ice2
#       ├──swh_ocean_mle3
#       ├──sig0_ocean_mle3_compression_qual
#       ├──sig0_ocog
#       ├──sig0_ice2
#       ├──slope1_ice2
#       └──sig0_leading_edge_ice2
